# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as pyplot

# %%
#Read in the dataset
df = pd.read_csv(r"C:\Users\SIMIYOUNG\Desktop\R folder\Hr _Attrition\attrition.csv")
df.describe()
# Out:
#          Unnamed: 0        Emp ID  satisfaction_level  last_evaluation  \
# count  14999.000000  14999.000000        14999.000000     14999.000000
# mean    7500.000000   7500.000000            0.612834         0.716102
# std     4329.982679   4329.982679            0.248631         0.171169
# min        1.000000      1.000000            0.090000         0.360000
# 25%     3750.500000   3750.500000            0.440000         0.560000
# 50%     7500.000000   7500.000000            0.640000         0.720000
# 75%    11249.500000  11249.500000            0.820000         0.870000
# max    14999.000000  14999.000000            1.000000         1.000000
#
#        number_project  average_montly_hours  time_spend_company  \
# count    14999.000000          14999.000000        14999.000000
# mean         3.803054            201.050337            3.498233
# std          1.232592             49.943099            1.460136
# min          2.000000             96.000000            2.000000
# 25%          3.000000            156.000000            3.000000
# 50%          4.000000            200.000000            3.000000
# 75%          5.000000            245.000000            4.000000
# max          7.000000            310.000000           10.000000
#
#        Work_accident  promotion_last_5years
# count   14999.000000           14999.000000
# mean        0.144610               0.021268
# std         0.351719               0.144281
# min         0.000000               0.000000
# 25%         0.000000               0.000000
# 50%         0.000000               0.000000
# 75%         0.000000               0.000000
# max         1.000000               1.000000

# %%
#Some correlation stats
cor = df.corr()

sns.heatmap(cor, 
            vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True)

# %%
df
# Out:
#        Unnamed: 0  Emp ID  satisfaction_level  last_evaluation  \
# 0               1    2001                0.58             0.74
# 1               2    2002                0.82             0.67
# 2               3    2003                0.45             0.69
# 3               4    2004                0.78             0.82
# 4               5    2005                0.49             0.60
# 5               6    2006                0.36             0.95
# 6               7    2007                0.54             0.37
# 7               8    2008                0.99             0.91
# 8               9    2009                0.50             0.75
# 9              10    2010                0.74             0.64
# 10             11    2011                0.56             0.58
# 11             12    2012                0.34             0.39
# 12             13    2013                0.48             0.94
# 13             14    2014                0.73             0.62
# 14             15    2015                0.59             0.87
# 15             16    2016                0.81             0.57
# 16             17    2017                0.90             0.66
# 17             18    2018                0.41             0.84
# 18             19    2019                0.89             0.92
# 19             20    2020                0.48             0.84
# 20             21    2021                0.79             0.97
# 21             22    2022                0.98             0.66
# 22             23    2023                0.75             0.70
# 23             24    2024                1.00             0.41
# 24             25    2025                0.24             0.82
# 25             26    2026                0.84             0.43
# 26             27    2027                0.56             0.86
# 27             28    2028                0.92             0.93
# 28             29    2029                0.61             0.98
# 29             30    2030                0.84             0.77
# ...           ...     ...                 ...              ...
# 14969       14970   14970                0.43             0.46
# 14970       14971   14971                0.78             0.93
# 14971       14972   14972                0.39             0.45
# 14972       14973   14973                0.11             0.97
# 14973       14974   14974                0.36             0.52
# 14974       14975   14975                0.36             0.54
# 14975       14976   14976                0.10             0.79
# 14976       14977   14977                0.40             0.47
# 14977       14978   14978                0.81             0.85
# 14978       14979   14979                0.40             0.47
# 14979       14980   14980                0.09             0.93
# 14980       14981   14981                0.76             0.89
# 14981       14982   14982                0.73             0.93
# 14982       14983   14983                0.38             0.49
# 14983       14984   14984                0.72             0.84
# 14984       14985   14985                0.40             0.56
# 14985       14986   14986                0.91             0.99
# 14986       14987   14987                0.85             0.85
# 14987       14988   14988                0.90             0.70
# 14988       14989   14989                0.46             0.55
# 14989       14990   14990                0.43             0.57
# 14990       14991   14991                0.89             0.88
# 14991       14992   14992                0.09             0.81
# 14992       14993   14993                0.40             0.48
# 14993       14994   14994                0.76             0.83
# 14994       14995   14995                0.40             0.57
# 14995       14996   14996                0.37             0.48
# 14996       14997   14997                0.37             0.53
# 14997       14998   14998                0.11             0.96
# 14998       14999   14999                0.37             0.52
#
#        number_project  average_montly_hours  time_spend_company  \
# 0                   4                   215                   3
# 1                   2                   202                   3
# 2                   5                   193                   3
# 3                   5                   247                   3
# 4                   3                   214                   2
# 5                   3                   206                   4
# 6                   2                   176                   2
# 7                   5                   136                   4
# 8                   6                   127                   3
# 9                   4                   268                   3
# 10                  4                   258                   3
# 11                  2                   136                   3
# 12                  5                   255                   6
# 13                  3                   218                   3
# 14                  3                   268                   4
# 15                  3                   224                   2
# 16                  3                   231                   3
# 17                  6                   191                   6
# 18                  4                   165                   5
# 19                  4                   252                   3
# 20                  5                   266                   2
# 21                  5                   248                   3
# 22                  4                   144                   4
# 23                  4                   174                   3
# 24                  5                   179                   6
# 25                  6                   246                   4
# 26                  4                   201                   3
# 27                  4                   208                   3
# 28                  3                   267                   3
# 29                  4                   262                   4
# ...               ...                   ...                 ...
# 14969               2                   157                   3
# 14970               4                   225                   5
# 14971               2                   140                   3
# 14972               6                   310                   4
# 14973               2                   143                   3
# 14974               2                   153                   3
# 14975               7                   310                   4
# 14976               2                   136                   3
# 14977               4                   251                   6
# 14978               2                   144                   3
# 14979               6                   296                   4
# 14980               5                   238                   5
# 14981               5                   162                   4
# 14982               2                   137                   3
# 14983               5                   257                   5
# 14984               2                   148                   3
# 14985               5                   254                   5
# 14986               4                   247                   6
# 14987               5                   206                   4
# 14988               2                   145                   3
# 14989               2                   159                   3
# 14990               5                   228                   5
# 14991               6                   257                   4
# 14992               2                   155                   3
# 14993               6                   293                   6
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  promotion_last_5years        dept  salary status
# 0                  0                      0       sales     low  exist
# 1                  0                      0       sales     low  exist
# 2                  0                      0       sales     low  exist
# 3                  0                      0       sales     low  exist
# 4                  0                      0       sales     low  exist
# 5                  0                      0       sales     low  exist
# 6                  0                      0       sales     low  exist
# 7                  0                      0       sales     low  exist
# 8                  0                      0       sales     low  exist
# 9                  0                      0       sales     low  exist
# 10                 0                      0       sales  medium  exist
# 11                 0                      0       sales  medium  exist
# 12                 0                      0  accounting  medium  exist
# 13                 0                      0  accounting  medium  exist
# 14                 0                      0  accounting  medium  exist
# 15                 0                      0          hr  medium  exist
# 16                 0                      0          hr  medium  exist
# 17                 0                      0          hr  medium  exist
# 18                 0                      0          hr  medium  exist
# 19                 0                      0   technical  medium  exist
# 20                 0                      0   technical  medium  exist
# 21                 0                      0   technical  medium  exist
# 22                 0                      0   technical    high  exist
# 23                 0                      0   technical     low  exist
# 24                 0                      0   technical  medium  exist
# 25                 0                      0   technical  medium  exist
# 26                 1                      0   technical  medium  exist
# 27                 0                      0   technical  medium  exist
# 28                 0                      0   technical     low  exist
# 29                 0                      0   technical     low  exist
# ...              ...                    ...         ...     ...    ...
# 14969              0                      0       sales  medium   left
# 14970              0                      0       sales  medium   left
# 14971              0                      0       sales  medium   left
# 14972              0                      0  accounting  medium   left
# 14973              0                      0  accounting  medium   left
# 14974              0                      0  accounting  medium   left
# 14975              0                      0          hr  medium   left
# 14976              0                      0          hr  medium   left
# 14977              0                      0          hr  medium   left
# 14978              0                      0          hr  medium   left
# 14979              0                      0   technical  medium   left
# 14980              0                      0   technical    high   left
# 14981              0                      0   technical     low   left
# 14982              0                      0   technical  medium   left
# 14983              0                      0   technical  medium   left
# 14984              0                      0   technical  medium   left
# 14985              0                      0   technical  medium   left
# 14986              0                      0   technical     low   left
# 14987              0                      0   technical     low   left
# 14988              0                      0   technical     low   left
# 14989              1                      0   technical     low   left
# 14990              1                      0     support     low   left
# 14991              0                      0     support     low   left
# 14992              0                      0     support     low   left
# 14993              0                      0     support     low   left
# 14994              0                      0     support     low   left
# 14995              0                      0     support     low   left
# 14996              0                      0     support     low   left
# 14997              0                      0     support     low   left
# 14998              0                      0     support     low   left
#
# [14999 rows x 12 columns]

# %%
#Encode the salary column
lb_maker = LabelEncoder()
df["salary"] = lb_maker.fit_transform(df["salary"])

# %%
#Encode the department column
df["dept"] = lb_maker.fit_transform(df["dept"])

# %%
#Examine data after encoding the status column
df["status"] = lb_maker.fit_transform(df["status"])

#or

#Encoding the status column
#df["status"] = np.where(df["status"] ==  "left", 0, 1)

# %%
#Examine new data
df.describe()
# Out:
#          Unnamed: 0        Emp ID  satisfaction_level  last_evaluation  \
# count  14999.000000  14999.000000        14999.000000     14999.000000
# mean    7500.000000   7500.000000            0.612834         0.716102
# std     4329.982679   4329.982679            0.248631         0.171169
# min        1.000000      1.000000            0.090000         0.360000
# 25%     3750.500000   3750.500000            0.440000         0.560000
# 50%     7500.000000   7500.000000            0.640000         0.720000
# 75%    11249.500000  11249.500000            0.820000         0.870000
# max    14999.000000  14999.000000            1.000000         1.000000
#
#        number_project  average_montly_hours  time_spend_company  \
# count    14999.000000          14999.000000        14999.000000
# mean         3.803054            201.050337            3.498233
# std          1.232592             49.943099            1.460136
# min          2.000000             96.000000            2.000000
# 25%          3.000000            156.000000            3.000000
# 50%          4.000000            200.000000            3.000000
# 75%          5.000000            245.000000            4.000000
# max          7.000000            310.000000           10.000000
#
#        Work_accident  promotion_last_5years          dept        salary  \
# count   14999.000000           14999.000000  14999.000000  14999.000000
# mean        0.144610               0.021268      5.870525      1.347290
# std         0.351719               0.144281      2.868786      0.625819
# min         0.000000               0.000000      0.000000      0.000000
# 25%         0.000000               0.000000      4.000000      1.000000
# 50%         0.000000               0.000000      7.000000      1.000000
# 75%         0.000000               0.000000      8.000000      2.000000
# max         1.000000               1.000000      9.000000      2.000000
#
#              status
# count  14999.000000
# mean       0.238083
# std        0.425924
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
#Moving to extract the needed column
df2 = df.iloc[:, 2:]

#examine new dataset
df2.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident  \
# count          14999.000000        14999.000000   14999.000000
# mean             201.050337            3.498233       0.144610
# std               49.943099            1.460136       0.351719
# min               96.000000            2.000000       0.000000
# 25%              156.000000            3.000000       0.000000
# 50%              200.000000            3.000000       0.000000
# 75%              245.000000            4.000000       0.000000
# max              310.000000           10.000000       1.000000
#
#        promotion_last_5years          dept        salary        status
# count           14999.000000  14999.000000  14999.000000  14999.000000
# mean                0.021268      5.870525      1.347290      0.238083
# std                 0.144281      2.868786      0.625819      0.425924
# min                 0.000000      0.000000      0.000000      0.000000
# 25%                 0.000000      4.000000      1.000000      0.000000
# 50%                 0.000000      7.000000      1.000000      0.000000
# 75%                 0.000000      8.000000      2.000000      0.000000
# max                 1.000000      9.000000      2.000000      1.000000

# %%
#Convert to array
array = df2.values

#Spliiting the dataset
X = array[:,0:9]
y = array[:,9]

#Traintest
X_train, X_validation, y_train, y_validation = train_test_split(X, y, random_state = 1, test_size = 0.20)

# %%
#Import all neccessary model for training
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
#Append all needed models
models = []
models.append(("LDA", LinearDiscriminantAnalysis()))
models.append(("LR", LogisticRegression(solver = "liblinear", multi_class = "ovr")))
models.append(("KNN", KNeighborsClassifier()))
models.append(("CART", DecisionTreeClassifier()))
models.append(("NB", GaussianNB()))
models.append(("SVM", SVC(gamma ="auto")))
models.append(("RF", RandomForestClassifier(n_estimators = 100)))

# %%
results = []
names = []
for name, model in models:
    kfold = StratifiedKFold(n_splits = 10, random_state = 1, shuffle = True)
    cv_results = cross_val_score(model, X_train, y_train, cv = kfold, scoring = "accuracy")
    results.append(cv_results)
    names.append(name)
    print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# LDA: 0.765148 (0.008840)
# LR: 0.768148 (0.009994)
# KNN: 0.930828 (0.009403)
# CART: 0.976332 (0.004235)
# NB: 0.800234 (0.009141)
# SVM: 0.946579 (0.008882)
# RF: 0.990915 (0.002751)

# %%
#A useful way to compare the samples of results for each algorithm is to create a box 
#and whisker plot for each distribution and compare the distributions.
pyplot.boxplot(results, labels = names)
pyplot.title("Model Distribution")
pyplot.show()

# %%
#Lets make some prediction with the model
model = RandomForestClassifier(n_estimators = 100)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#Make predictions
prediction = model.predict(X_validation)

# %%
#Examine a confusion matrix
confusion_matrix(prediction, y_validation)
# Out:
# array([[2271,   16],
#        [   5,  708]], dtype=int64)

# %%
#test accuracy
print(accuracy_score(y_validation, prediction))
# Out:
# 0.993

# %%
print(classification_report(y_validation, prediction))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      2276
#          1.0       0.99      0.98      0.99       724
#
#     accuracy                           0.99      3000
#    macro avg       0.99      0.99      0.99      3000
# weighted avg       0.99      0.99      0.99      3000
